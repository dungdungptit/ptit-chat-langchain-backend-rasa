# %%
import os

os.environ["GOOGLE_CSE_ID"] = "a22ff93cea14f4de4"
os.environ["GOOGLE_API_KEY"] = "AIzaSyCwlycdvOFOqmBLsJUvh9kyAAOX3bNjf3U"

# %%
from langchain_community.utilities import GoogleSearchAPIWrapper
from langchain_core.tools import Tool

search = GoogleSearchAPIWrapper(k=5)

tool = Tool(
    name="google_search",
    description="Search Google for recent results.",
    func=search.run,
)

# %%
tool.run("Nhiệt độ hôm nay tại Hà Nội")
# Out:
# 'Thời tiết Hà Nội. Thời tiết hiện tại. Cập nhật: 4h ... Dự báo ngày hôm nay. Cập nhật: Nhiệt độ. : °C. Độ ẩm ... phường Láng Thượng, quận Đống Đa, thành phố Hà Nội. Nhiệt độ Hà Nội - Khám phá nhiệt độ ngày hôm nay, ngày mai và trong 5 ngày tiếp theo tại Hà Nội - ThoitTietHanoi.com. Mar 29, 2024 ... - Nhiệt độ dao động trong khoảng 27 - 28 độ, ít thay đổi so với ngày hôm trước. Độ ẩm tương đối phổ biến 69 - 81%, mật độ mây khá cao 62 - 92%. Jan 29, 2024 ... VTV.vn - Trung tâm Dự báo Khí tượng Thủy văn Quốc gia vừa cập nhật nhiệt độ lúc 6h sáng nay (29/1) tại Hà Nội và các khu vực khác. Feb 29, 2024 ... - Nhiệt độ vẫn dao động trong khoảng 20 - 21 độ. Độ ẩm tương đối phổ biến 80 - 88%, mật độ mây 92 - 100%. - Hướng gió: Đông Đông Nam đến Đông\xa0...'

# %%
search.results("Nhiệt độ hôm nay tại Cầu giấy Hà Nội", 5)
# Out:
# [{'title': 'Thời tiết hàng giờ ở Cầu Giấy, Hà Nội, Việt Nam | AccuWeather',
#   'link': 'https://www.accuweather.com/vi/vn/cau-giay/3558163/hourly-weather-forecast/3558163',
#   'snippet': 'RealFeel Shade™81°. GióN 5 mi/h. Chất lượng không khíCó hại. Chỉ số UV tối đa0 Thấp. Gió giật12 mi/h. Độ ẩm90%. Điểm sương72° F. Mật độ mây100%.'},
#  {'title': 'Dự báo thời tiết Cầu Giấy, Hà Nội hôm nay, ngày mai và nhiều ngày ...',
#   'link': 'https://thoitiet.edu.vn/ha-noi/cau-giay',
#   'snippet': 'Nhiệt độ và khả năng có mưa Cầu Giấy - Hà Nội trong 12h tới. Nhiệt độ và khả năng có mưa Cầu Giấy - Hà Nội những ngày tới. Lượng mưa Cầu Giấy - Hà Nội những\xa0...'},
#  {'title': 'Dự báo thời tiết ba ngày ở Cầu Giấy, Hà Nội, Việt Nam | AccuWeather',
#   'link': 'https://www.accuweather.com/vi/vn/cau-giay/3558163/weather-forecast/3558163',
# ...

# %%
links = [i['link'] for i in search.results("Nhiệt độ hôm nay tại Cầu giấy Hà Nội", 5)]
print(links)
# Out:
# ['https://www.accuweather.com/vi/vn/cau-giay/3558163/hourly-weather-forecast/3558163', 'https://thoitiet.edu.vn/ha-noi/cau-giay', 'https://www.accuweather.com/vi/vn/cau-giay/3558163/weather-forecast/3558163', 'https://thoitiet.vn/ha-noi/cau-giay', 'https://laodong.vn/video-xa-hoi/ban-tin-du-bao-thoi-tiet-dem-nay-va-ngay-mai-251-1296620.ldo']

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(
    web_paths=(links),
    # bs_kwargs=dict(
    #     parse_only=bs4.SoupStrainer(
    #         class_=("post-content", "post-title", "post-header")
    #     )
    # ),
    
)

data = loader.load()
data
# Out:
# [Document(page_content='\n\n\n\n\n\n\nThời tiết hàng giờ ở Cầu Giấy, Hà Nội, Việt Nam | AccuWeather\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\tQuay lại\n\t\n\n\n\n\n\n\nCầu Giấy, Hà Nội\n31°C\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSử dụng địa điểm hiện tại\n\n\nGần đây\n\n\nCầu Giấy\nHà Nội\n\n\n31°\n\n\n\n\n\n\n\n\nKhông tìm thấy kết quả.\nHãy thử tìm thành phố, mã zip hoặc điểm quan tâm.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t\t\t\tcài đặt\n\t\t\t\n\n\nCầu Giấy, Hà Nội Thời tiết\nH.nay\nWinterCast\nỨng dụng theo dõi {stormName} tại địa phương\nTheo giờ\nHàng ngày\nRa-đa\nMinuteCast\nHàng tháng\nChất lượng không khí\nSức khỏe và hoạt động\n\n\nToàn cầu\n\n\nGió xoáy\n\n\n\nRađa & bản đồ\n\n\n\nVideo\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nH.nay\n\n\nTheo giờ\n\n\nHàng ngày\n\n\nRa-đa\n\n\nMinuteCast\n\n\nHàng tháng\n\n\nChất lượng không khí\n\n\nSức khỏe và hoạt động\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n15\
# ...

# %%
import re
string_data = "\n\n".join([i.page_content for i in data])
cleaned_text = re.sub(r'(\n\s*)+', ' ', string_data).strip()

print(cleaned_text)
# Out:
# Thời tiết hàng giờ ở Cầu Giấy, Hà Nội, Việt Nam | AccuWeather Quay lại Cầu Giấy, Hà Nội 31°C Sử dụng địa điểm hiện tại Gần đây Cầu Giấy Hà Nội 31° Không tìm thấy kết quả. Hãy thử tìm thành phố, mã zip hoặc điểm quan tâm. cài đặt Cầu Giấy, Hà Nội Thời tiết H.nay WinterCast Ứng dụng theo dõi {stormName} tại địa phương Theo giờ Hàng ngày Ra-đa MinuteCast Hàng tháng Chất lượng không khí Sức khỏe và hoạt động Toàn cầu Gió xoáy Rađa & bản đồ Video H.nay Theo giờ Hàng ngày Ra-đa MinuteCast Hàng tháng Chất lượng không khí Sức khỏe và hoạt động 15 31° RealFeel® 33° Nóng 20% Chevron down Có mây RealFeel Shade™32° GióĐN 13 km/h Chất lượng không khíXấu Chỉ số UV tối đa1 Thấp Gió giật20 km/h Độ ẩm59% Điểm sương22° C Mật độ mây96% Tầm nhìn10 km Trần mây500 m 16 30° RealFeel® 32° Nóng 20% Chevron down Có mây RealFeel Shade™32° GióĐN 15 km/h Chất lượng không khíXấu Chỉ số UV tối đa1 Thấp Gió giật20 km/h Độ ẩm60% Điểm sương22° C Mật độ mây99% Tầm nhìn10 km Trần mây500 m 17 29° RealFeel® 31° Rất ấm áp
# ...

# %%
list_dir = ["Thông tin trường",
"Cơ sở đào tạo",
"Ngành/Chuyên ngành",
"Ban tuyển sinh",
"Phương thức xét tuyển",
"Chỉ tiêu tuyển sinh",
"Điểm trúng tuyển",
"Đối tượng ưu tiên, khu vực ưu tiên",
"Lệ phí",
"Học phí",
"Chính sách hỗ trợ, ưu tiên",
"Học bổng",
"Cơ hội việc làm",
"Ký túc xá",
"Hợp tác đối ngoại",
"Hình thức đào tạo",
"Nhập học"]

# %%
import os

parent_dir = "../DataFTU/DataCheckList"

for dir_name in list_dir:
    dir_name = dir_name.replace(" ", "_")
    path = os.path.join(parent_dir, dir_name)
    os.makedirs(path, exist_ok=True)
